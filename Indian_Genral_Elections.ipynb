# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('results_2024_winners.csv')

# %%
df
# Out:
#                  State  PC No          PC Name  \
# 0       Andhra Pradesh      7  Amalapuram (SC)
# 1       Andhra Pradesh      5       Anakapalle
# 2       Andhra Pradesh     19       Ananthapur
# 3       Andhra Pradesh      1       Araku (ST)
# 4       Andhra Pradesh     15     Bapatla (SC)
# ..                 ...    ...              ...
# 538  Jammu and Kashmir      1        BARAMULLA
# 539  Jammu and Kashmir      5            JAMMU
# 540  Jammu and Kashmir      2         SRINAGAR
# 541  Jammu and Kashmir      4         UDHAMPUR
# 542             Ladakh      1           Ladakh
#
#                     Winning Candidate                          Winning Party  \
# 0               G M HARISH (BALAYOGI)                           Telugu Desam
# 1                          C.M.RAMESH                 Bharatiya Janata Party
# 2    AMBICA G LAKSHMINARAYANA VALMIKI                           Telugu Desam
# 3                  GUMMA THANUJA RANI  Yuvajana Sramika Rythu Congress Party
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                543 non-null    object
#  1   PC No                543 non-null    int64
#  2   PC Name              543 non-null    object
#  3   Winning Candidate    543 non-null    object
#  4   Winning Party        543 non-null    object
#  5   Runner-up Canddiate  542 non-null    object
#  6   Runner-up Party      542 non-null    object
#  7   Margin Votes         543 non-null    object
#  8   Results Status       543 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 38.3+ KB

# %%
df.describe()
# Out:
#             PC No
# count  543.000000
# mean    18.178637
# std     16.427840
# min      1.000000
# 25%      6.000000
# 50%     14.000000
# 75%     25.000000
# max     80.000000

# %%
df.shape
# Out:
# (543, 9)

# %%
df.isnull().sum()
# Out:
# State                  0
# PC No                  0
# PC Name                0
# Winning Candidate      0
# Winning Party          0
# Runner-up Canddiate    1
# Runner-up Party        1
# Margin Votes           0
# Results Status         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['State', 'PC No', 'PC Name', 'Winning Candidate', 'Winning Party',
#        'Runner-up Canddiate', 'Runner-up Party', 'Margin Votes',
#        'Results Status'],
#       dtype='object')

# %%
parties=df['Winning Party'].unique()

# %%
len(parties)
# Out:
# 42

# %%
parties
# Out:
# array(['Telugu Desam', 'Bharatiya Janata Party',
#        'Yuvajana Sramika Rythu Congress Party', 'Janasena Party',
#        'Asom Gana Parishad', 'Indian National Congress',
#        'United People’s Party, Liberal',
#        'Communist Party of India  (Marxist-Leninist)  (Liberation)',
#        'Rashtriya Janata Dal', 'Janata Dal  (United)',
#        'Hindustani Awam Morcha (Secular)',
#        'Lok Janshakti Party(Ram Vilas)', 'Independent',
#        'Janata Dal  (Secular)', 'Communist Party of India  (Marxist)',
#        'Revolutionary Socialist Party', 'Kerala Congress',
#        'Indian Union Muslim League',
#        'Nationalist Congress Party – Sharadchandra Pawar', 'Shiv Sena',
#        'Shiv Sena (Uddhav Balasaheb Thackrey)',
#        'Nationalist Congress Party', 'Voice of the People Party',
#        'Zoram People’s Movement', 'Aam Aadmi Party',
#        'Shiromani Akali Dal', 'Bharat Adivasi Party',
#        'Rashtriya Loktantrik Party', 'Sikkim Krantikari Morcha',
# ...

# %% [markdown]
# __Results of Lok Sabha Elections 2024__

# %%
df['Winning Party'].groupby(df['Winning Party']).count().sort_values(ascending=False).head(10)
# Out:
# Winning Party
# Bharatiya Janata Party                              240
# Indian National Congress                             99
# Samajwadi Party                                      37
# All India Trinamool Congress                         29
# Dravida Munnetra Kazhagam                            22
# Telugu Desam                                         16
# Janata Dal  (United)                                 12
# Shiv Sena (Uddhav Balasaheb Thackrey)                 9
# Nationalist Congress Party – Sharadchandra Pawar      8
# Shiv Sena                                             7
# Name: Winning Party, dtype: int64

# %%
labels=['Bharatiya Janata Party','Indian National Congress','Samajwadi Party','All India Trinamool Congress','Dravida Munnetra Kazhagam',
       'Telugu Desam','Janata Dal  (United)','Shiv Sena (Uddhav Balasaheb Thackrey)','Nationalist Congress Party – Sharadchandra Pawar','Shiv Sena']

# %%
len(labels)
# Out:
# 10

# %% [markdown]
# __Seats won by Top 10 parties__

# %%
plt.pie(df['Winning Party'].groupby(df['Winning Party']).count().sort_values(ascending=False).head(10),labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dcce5bdd90>,
# ...
#  [Text(-0.003607301406907855, 1.0999940851552612, 'Bharatiya Janata Party'),
#   Text(-0.8717728222621446, -0.6708294465548567, 'Indian National Congress'),
#   Text(-0.02524849985450834, -1.0997101951219226, 'Samajwadi Party'),
#   Text(0.4383851165621134, -1.008869907161881, 'All India Trinamool Congress'),
#   Text(0.7452890973356437, -0.8090390357656553, 'Dravida Munnetra Kazhagam'),
#   Text(0.9218166233063676, -0.6002117234743474, 'Telugu Desam'),
#   Text(1.0159220621093739, -0.42178473623335144, 'Janata Dal  (United)'),
#   Text(1.0642108629297633, -0.27830781380027564, 'Shiv Sena (Uddhav Balasaheb Thackrey)'),
#   Text(1.0885690386711722, -0.15816904895244321, 'Nationalist Congress Party – Sharadchandra Pawar'),
#   Text(1.0988409292029921, -0.05048378262674709, 'Shiv Sena')])

# %% [markdown]
# __State wise performance of BJP and Congress__

# %%
df['State'][df['Winning Party']=='Bharatiya Janata Party'].groupby(df['State']).count().sort_values(ascending=False)
# Out:
# State
# Uttar Pradesh                           33
# Madhya Pradesh                          29
# Gujarat                                 25
# Odisha                                  20
# Karnataka                               17
# Rajasthan                               14
# West Bengal                             12
# Bihar                                   12
# Chhattisgarh                            10
# Assam                                    9
# Maharashtra                              9
# Telangana                                8
# Jharkhand                                8
# NCT OF Delhi                             7
# Haryana                                  5
# Uttarakhand                              5
# Himachal Pradesh                         4
# Andhra Pradesh                           3
# Jammu and Kashmir                        2
# Tripura                                  2
# Arunachal Pradesh                        2
# Kerala                                   1
# ...

# %%
df['State'][df['Winning Party']=='Indian National Congress'].groupby(df['State']).count().sort_values(ascending=False)
# Out:
# State
# Kerala           14
# Maharashtra      13
# Tamil Nadu        9
# Karnataka         9
# Telangana         8
# Rajasthan         8
# Punjab            7
# Uttar Pradesh     6
# Haryana           5
# Bihar             3
# Assam             3
# Manipur           2
# Jharkhand         2
# Lakshadweep       1
# Meghalaya         1
# Nagaland          1
# Odisha            1
# Puducherry        1
# Gujarat           1
# Goa               1
# Chhattisgarh      1
# Chandigarh        1
# West Bengal       1
# Name: State, dtype: int64

# %% [markdown]
# __Top Closely contested seats and one sided victories__

# %%
df['Margin Votes'] = pd.to_numeric(df['Margin Votes'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                543 non-null    object
#  1   PC No                543 non-null    int64
#  2   PC Name              543 non-null    object
#  3   Winning Candidate    543 non-null    object
#  4   Winning Party        543 non-null    object
#  5   Runner-up Canddiate  542 non-null    object
#  6   Runner-up Party      542 non-null    object
#  7   Margin Votes         542 non-null    float64
#  8   Results Status       543 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 38.3+ KB

# %%
df[df['Margin Votes']<3000]
# Out:
#              State  PC No            PC Name          Winning Candidate  \
# 153         Kerala     19           Attingal          ADV ADOOR PRAKASH
# 225    Maharashtra     27  Mumbai North West   RAVINDRA DATTARAM WAIKAR
# 264         Odisha      8             Jajpur    RABINDRA NARAYAN BEHERA
# 300      Rajasthan      6       JAIPUR RURAL         RAO RAJENDRA SINGH
# 383  Uttar Pradesh     40        Farrukhabad              MUKESH RAJPUT
# 393  Uttar Pradesh     47           Hamirpur        AJENDRA SINGH LODHI
# 481   Chhattisgarh     11             KANKER                BHOJRAJ NAG
# 525     Chandigarh      1         Chandigarh              MANISH TEWARI
# 535    Lakshadweep      1        Lakshadweep  MUHAMMED HAMDULLAH SAYEED
#
#                 Winning Party              Runner-up Canddiate  \
# 153  Indian National Congress                            V JOY
# 225                 Shiv Sena            AMOL GAJANAN KIRTIKAR
# ...

# %%
df[df['Margin Votes']>500000]
# Out:
#               State  PC No              PC Name  \
# 23   Andhra Pradesh      4        Visakhapatnam
# 29            Assam      2              Dhubri
# 93          Gujarat      6          Gandhinagar
# 99          Gujarat     25              Navsari
# 100         Gujarat     18           Panchmahal
# 107         Gujarat     20             Vadodara
# 174  Madhya Pradesh     19               BHOPAL
# 179  Madhya Pradesh      4                 GUNA
# 182  Madhya Pradesh     26               INDORE
# 184  Madhya Pradesh      8            KHAJURAHO
# 188  Madhya Pradesh     23             MANDSOUR
# 199  Madhya Pradesh     18              VIDISHA
# 348      Tamil Nadu      1           TIRUVALLUR
# 354         Tripura      1         Tripura West
# 387   Uttar Pradesh     13  Gautam Buddha Nagar
# 452     West Bengal     21      Diamond harbour
# 485    Chhattisgarh      8               RAIPUR
# 518       Telangana     13             Nalgonda
#
# ...
